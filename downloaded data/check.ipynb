# %%
import pandas as pd
df = pd.read_csv("Metadata_Indicator_API_AFG_DS2_en_csv_v2_3436225.csv")
df.to_json("Metadata_json")

# %%
df = pd.read_json("Metadata_json.json")

# %%
import requests
import io
import pandas as pd

# URL for the World Bank API data for Afghanistan
url = "https://api.worldbank.org/v2/en/country/AFG?downloadformat=csv"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Read the content of the response
    content = response.content
    
    # Use StringIO to create a file-like object from the content
    csv_file = io.StringIO(content.decode('utf-8'))
    
    # Read the CSV data into a pandas DataFrame
    df_afghanistan = pd.read_csv(csv_file)
    
    # Display the first few rows of the dataframe
    print(df_afghanistan.head())
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[14], line 17
#      14 content = response.content
#      16 # Use StringIO to create a file-like object from the content
# ---> 17 csv_file = io.StringIO(content.decode('utf-8'))
#      19 # Read the CSV data into a pandas DataFrame
#      20 df_afghanistan = pd.read_csv(csv_file)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xaf in position 14: invalid start byte

# %%
import pandas as pd

# Read the CSV file, skipping the first 4 rows and using '","' as the separator
df = pd.read_csv("API_AFG_DS2_en_csv_v2_3436225.csv", 
                 skiprows=4, 
                 sep='","',
                 engine='python',
                 quotechar='"',
                 na_values=[''])

# Clean up column names
df.columns = df.columns.str.replace('"', '')

# Display the first few rows of the dataframe
df.head()
# Out:
#    Country Name Country Code  \
# 0  "Afghanistan          AFG
# 1  "Afghanistan          AFG
# 2  "Afghanistan          AFG
# 3  "Afghanistan          AFG
# 4  "Afghanistan          AFG
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Intentional homicides, female (per 100,000 fem...  VC.IHR.PSRC.FE.P5   NaN
# 1           Battle-related deaths (number of people)        VC.BTL.DETH   NaN
# 2          Voice and Accountability: Percentile Rank         VA.PER.RNK   NaN
# 3  Transport services (% of commercial service ex...  TX.VAL.TRAN.ZS.WT   NaN
# 4  Computer, communications and other services (%...  TX.VAL.OTHR.ZS.WT   NaN
#
#    1961  1962  1963  1964  1965  ...          2014          2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...  12284.000000  17278.000000
# 2   NaN   NaN   NaN   NaN   NaN  ...     16.256157     18.719212
# ...
